# %%
#1 Stack implementation using array

'''
Stack Operations:-
1.Push operation
2.Pop operation
3.Accessing Top element
4.free space 
5.Peep operarion
6.Change or Update operation
'''

class Stack:
    def __init__(self):
        self.size = 5
        self.MAX = size-1
        self.TOP = -1
        self.stack = [None for i in range(size)]

        
    def push(self):
        if self.TOP == MAX:
            print("Overflow! Stack is Full")
        else:
            self.TOP = self.TOP+1
            item = int(input("Enter item in stack: "))
            self.stack[self.TOP] = item
            print("Item is inserted successfully.")
        
        
    def pop(self):
        if self.TOP == -1:
            print("Underflow! Stack is empty.")
        else:
            self.stack[self.TOP] = None
            self.TOP = self.TOP-1
            print("Item is deleted successfully.") 
    
    
    def top_element(self):
        print("Top element: ", self.stack[TOP])
        
        
    def free_space(self):
        free = (self.size-self.TOP)/self.size*100
        print("freely space of stack: ", free,"%")
        
        
    def peep(self):
        i = int(input("Enter the ith number of item from top: "))
        
        if self.TOP-i+1 <= 0:
            print("Underflow! Not enough items present in stack.")
        else:
            print("Item is: ", self.stack[self.TOP-i+1])
        
        
    def update(self):
        i = int(input("Enter the ith number of item from top which you want to update: "))
        
        if self.TOP-i+1 <= 0:
            print("Underflow! Not enough items present in stack.")
        else:
            x = int(input("Enter new value: "))
            self.stack[self.TOP-i+1] = x
            print("Value changes successfully.")
            
            
stack = Stack()

print("Stack operations:-\n1.Push operation\n2.Pop operation\n3.Accessing Top element\n4.free space \n5.Peep operarion\n6.Change or Update operation\n7.Exit")

while True:
    choice = int(input("Enter your choice(in numeric type): "))

    if choice == 1:
        stack.push()
    elif choice == 2:
        stack.pop()
    elif choice == 3:
        stack.top_element()
    elif choice == 4:
        stack.free_space()
    elif choice == 5:
        stack.peep()
    elif choice == 6:
        stack.update()
    elif choice == 7:
        break
    else:
        print("Please enter choice from 1 to 7")
